# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("matches.csv")
data
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5        6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6        7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7        8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8        9    2017           Pune  2017-04-11             Delhi Daredevils
# 9       10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10      11    2017        Kolkata  2017-04-13              Kings XI Punjab
# ...

# %% [markdown]
# # Which team has won maximum matches while chasing

# %%
a=data.query("team2 == winner ")
b=a["winner"].value_counts()
b
# Out:
# Kolkata Knight Riders          58
# Mumbai Indians                 51
# Chennai Super Kings            49
# Royal Challengers Bangalore    49
# Rajasthan Royals               46
# Kings XI Punjab                44
# Delhi Daredevils               42
# Sunrisers Hyderabad            28
# Gujarat Lions                  12
# Deccan Chargers                11
# Delhi Capitals                  7
# Pune Warriors                   6
# Rising Pune Supergiants         5
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Name: winner, dtype: int64

# %%
df1= pd.DataFrame(data=b.index, columns=['winner'])
df2 = pd.DataFrame(data=b.values, columns=['value'])
d2 = pd.merge(df1, df2, left_index=True, right_index=True)
df3 = d2.iloc[[0,-1]]
df3
# Out:
#                    winner  value
# 0   Kolkata Knight Riders     58
# 14   Kochi Tuskers Kerala      4

# %% [markdown]
# # Which toss decision is best for each ground

# %%
batting_wins=data[data["team1"]==data["winner"]]
fielding_wins=data[data["team2"]==data["winner"]]
grounds=team1["venue"].value_counts().index
for ground in grounds:
    if(batting_wins['venue'].value_counts()[ground]>fielding_wins['venue'].value_counts()[ground]):
        print(ground + 'is best for batting')
    else:
        print(ground + 'is best for batting')
# Out:
# Wankhede Stadiumis best for batting
# Feroz Shah Kotlais best for batting
# MA Chidambaram Stadium, Chepaukis best for batting
# Eden Gardensis best for batting
# M Chinnaswamy Stadiumis best for batting
# Rajiv Gandhi International Stadium, Uppalis best for batting
# Punjab Cricket Association Stadium, Mohaliis best for batting
# Sawai Mansingh Stadiumis best for batting
# Subrata Roy Sahara Stadiumis best for batting
# Kingsmeadis best for batting
# Maharashtra Cricket Association Stadiumis best for batting
# Punjab Cricket Association IS Bindra Stadium, Mohaliis best for batting
# Dr DY Patil Sports Academyis best for batting
# Brabourne Stadiumis best for batting
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadiumis best for batting
# Sardar Patel Stadium, Moterais best for batting
# Himachal Pradesh Cricket Association Stadiumis best for batting
# Rajiv Gandhi Intl. Cricket Stadiumis best for batting
# Newlandsis best for batting
# SuperSport Parkis best for batting
# ...

# %% [markdown]
# # Player who has maximum man of the match while chasing

# %%
a=data.query("team2 == winner")
b=a["player_of_match"].value_counts()
b
# Out:
# YK Pathan           11
# G Gambhir           10
# CH Gayle            10
# RG Sharma            9
# DR Smith             9
# SR Watson            9
# JH Kallis            8
# V Kohli              8
# AB de Villiers       8
# DA Warner            8
# MS Dhoni             8
# AD Russell           7
# AM Rahane            7
# V Sehwag             7
# UT Yadav             6
# AC Gilchrist         5
# A Mishra             5
# SP Narine            5
# SE Marsh             5
# SK Raina             5
# F du Plessis         4
# Harbhajan Singh      4
# RR Pant              4
# MEK Hussey           4
# Rashid Khan          4
# DPMD Jayawardene     4
# RA Jadeja            4
# S Dhawan             4
# KL Rahul             4
# AT Rayudu            4
#                     ..
# IK Pathan            1
# SK Trivedi           1
# MJ Lumb              1
# R Sharma             1
# MS Bisla             1
# SB Wagh              1
# K Rabada             1
# WP Saha              1
# Yuvraj Singh         1
# ...

# %%
df1= pd.DataFrame(data=b.index, columns=['player_of_match'])
df2 = pd.DataFrame(data=b.values, columns=['value'])
d2 = pd.merge(df1, df2, left_index=True, right_index=True)
df3 = d2.iloc[[0]]
df3
# Out:
#   player_of_match  value
# 0       YK Pathan     11

# %%
data2=pd.read_csv("deliveries.csv")

# %%
data2
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 5              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 6              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 7              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 8              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 9              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 10             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...

# %% [markdown]
# # Batsman who have faced maximum dot balls

# %%
a=data2.query("wide_runs == '0' & batsman_runs == '0'")
b=a["batsman"].value_counts()
b
# Out:
# V Kohli             1404
# S Dhawan            1372
# RG Sharma           1330
# CH Gayle            1300
# RV Uthappa          1292
# SK Raina            1279
# G Gambhir           1234
# DA Warner           1177
# AM Rahane           1131
# SR Watson           1046
# MS Dhoni            1035
# PA Patel             982
# KD Karthik           958
# BB McCullum          943
# JH Kallis            913
# M Vijay              902
# AT Rayudu            898
# Yuvraj Singh         891
# AB de Villiers       886
# MK Pandey            835
# DR Smith             793
# R Dravid             783
# YK Pathan            780
# SR Tendulkar         778
# SE Marsh             694
# KA Pollard           684
# AC Gilchrist         677
# V Sehwag             659
# MEK Hussey           607
# NV Ojha              600
#                     ...
# Avesh Khan             2
# L Ablish               2
# KP Appanna             2
# RR Bhatkal             2
# DM Bravo               2
# L Plunkett             2
# ...

# %%
df1= pd.DataFrame(data=b.index, columns=['batsman'])
df2 = pd.DataFrame(data=b.values, columns=['dot_balls'])
d2 = pd.merge(df1, df2, left_index=True, right_index=True)
d2
df3 = d2.iloc[[0]]
df3
# Out:
#    batsman  dot_balls
# 0  V Kohli       1404

# %% [markdown]
# # which batsmen has come to crease but never faced a ball

# %%
data2=pd.read_csv("deliveries.csv")
c1=data2["batsman"]
d=data2[~data2['non_striker'].isin(c1)]
b=d["non_striker"]
b
# Out:
# 25297             A Nel
# 25298             A Nel
# 25299             A Nel
# 47770       C Ganapathy
# 47771       C Ganapathy
# 73812      TP Sudhindra
# 110217    BW Hilfenhaus
# Name: non_striker, dtype: object

# %%
df1= pd.DataFrame(data=b.index, columns=['match id'])
df2 = pd.DataFrame(data=b.values, columns=['dot_balls'])
d2 = pd.merge(df1, df2, left_index=True, right_index=True)
d2
# Out:
#    match id      dot_balls
# 0     25297          A Nel
# 1     25298          A Nel
# 2     25299          A Nel
# 3     47770    C Ganapathy
# 4     47771    C Ganapathy
# 5     73812   TP Sudhindra
# 6    110217  BW Hilfenhaus

# %% [markdown]
# # Which bowler have been scored maximum 1s

# %%
a=data2.query("total_runs=='1' & bye_runs == '0' & legbye_runs == '0'")
b=data2.query("total_runs=='2' & bye_runs == '0' & legbye_runs == '0'")
c=data2.query("total_runs=='3' & bye_runs == '0' & legbye_runs == '0'")
d=data2.query("total_runs=='4' & bye_runs == '0' & legbye_runs == '0'")
e=data2.query("total_runs=='6' & bye_runs == '0' & legbye_runs == '0'")
p=a["bowler"].value_counts()
q=b["bowler"].value_counts()
r=c["bowler"].value_counts()
s=d["bowler"].value_counts()
t=e["bowler"].value_counts()

# %%
df1= pd.DataFrame(data=p.index, columns=['bowler'])
df2 = pd.DataFrame(data=p.values, columns=['most_ones'])
d2 = pd.merge(df1, df2, left_index=True, right_index=True)
d2
df3 = d2.iloc[[0]]
df3
# Out:
#             bowler  most_ones
# 0  Harbhajan Singh       1513

# %% [markdown]
# # Which bowler have been scored maximum 2s

# %%
df1= pd.DataFrame(data=q.index, columns=['bowler'])
df2 = pd.DataFrame(data=q.values, columns=['most_twos'])
d2 = pd.merge(df1, df2, left_index=True, right_index=True)
d2
df3 = d2.iloc[[0]]
df3
# Out:
#      bowler  most_twos
# 0  DJ Bravo        258

# %% [markdown]
# # Which bowler have been scored maximum 3s

# %%
df1= pd.DataFrame(data=r.index, columns=['bowler'])
df2 = pd.DataFrame(data=r.values, columns=['most_threes'])
d2 = pd.merge(df1, df2, left_index=True, right_index=True)
d2
df3 = d2.iloc[[0]]
df3
# Out:
#     bowler  most_threes
# 0  P Kumar           18

# %% [markdown]
# # Which bowler have been scored maximum 4s

# %%
df1= pd.DataFrame(data=s.index, columns=['bowler'])
df2 = pd.DataFrame(data=s.values, columns=['most_fours'])
d2 = pd.merge(df1, df2, left_index=True, right_index=True)
d2
df3 = d2.iloc[[0]]
df3
# Out:
#      bowler  most_fours
# 0  UT Yadav         389

# %% [markdown]
# # Which bowler have been scored maximum 6s

# %%
df1= pd.DataFrame(data=t.index, columns=['bowler'])
df2 = pd.DataFrame(data=t.values, columns=['most_sixes'])
d2 = pd.merge(df1, df2, left_index=True, right_index=True)
d2
df3 = d2.iloc[[0]]
df3
# Out:
#       bowler  most_sixes
# 0  PP Chawla         171

# %% [markdown]
# # Which batsman stumped out maximum number of times

# %%
a=data2.query("dismissal_kind=='stumped'")
b=a["player_dismissed"].value_counts()
b
# Out:
# SK Raina            8
# AT Rayudu           7
# RV Uthappa          7
# AB de Villiers      6
# F du Plessis        6
# PA Patel            6
# M Vijay             5
# DA Warner           5
# S Dhawan            5
# KD Karthik          4
# AM Rahane           4
# MS Bisla            4
# WP Saha             4
# Mandeep Singh       4
# MK Tiwary           4
# MC Henriques        4
# NV Ojha             3
# KP Pietersen        3
# STR Binny           3
# S Badrinath         3
# SR Tendulkar        3
# V Kohli             3
# KC Sangakkara       3
# MS Dhoni            3
# AC Gilchrist        3
# SR Watson           3
# RG Sharma           3
# JC Buttler          3
# RE van der Merwe    3
# SK Warne            3
#                    ..
# S Hetmyer           1
# CH Morris           1
# S Anirudha          1
# SW Tait             1
# Ishan Kishan        1
# DJ Bravo            1
# MEK Hussey          1
# R Dhawan            1
# LRPL Taylor         1
# KK Cooper           1
# ...

# %%
df1= pd.DataFrame(data=b.index, columns=['batsman'])
df2 = pd.DataFrame(data=b.values, columns=['stumped_dismissal'])
d2 = pd.merge(df1, df2, left_index=True, right_index=True)
d2
df3 = d2.iloc[[0,1]]
df3
# Out:
#     batsman  stumped_dismissal
# 0  SK Raina                  8

# %% [markdown]
# # Which non-striker have been part of run outs maximum number of times

# %%
a=data2.query("dismissal_kind=='run out'")
b=a["non_striker"].value_counts()
b
# Out:
# KD Karthik          16
# SK Raina            16
# RG Sharma           15
# YK Pathan           14
# AB de Villiers      14
# RV Uthappa          14
# M Vijay             13
# AM Rahane           12
# PA Patel            11
# MS Dhoni            11
# SR Watson           10
# RA Jadeja           10
# G Gambhir           10
# S Dhawan            10
# Yuvraj Singh        10
# V Sehwag             8
# P Kumar              8
# IK Pathan            8
# DJ Hussey            8
# F du Plessis         8
# V Kohli              8
# Harbhajan Singh      8
# DPMD Jayawardene     7
# PP Chawla            7
# A Mishra             7
# JA Morkel            7
# KH Pandya            7
# AT Rayudu            7
# NV Ojha              7
# SL Malinga           7
#                     ..
# Sohail Tanvir        1
# VY Mahesh            1
# CH Morris            1
# Mashrafe Mortaza     1
# D du Preez           1
# Swapnil Singh        1
# BCJ Cutting          1
# UT Khawaja           1
# DJ Harris            1
# ...

# %%
df1= pd.DataFrame(data=b.index, columns=['non_striker'])
df2 = pd.DataFrame(data=b.values, columns=['runout_dismissal'])
d2 = pd.merge(df1, df2, left_index=True, right_index=True)
d2
df3 = d2.iloc[[0,1]]
df3
# Out:
#   non_striker  runout_dismissal
# 0  KD Karthik                16
# 1    SK Raina                16

# %% [markdown]
# # which team has played maximum super overs while defending

# %%
a=data2.query("is_super_over=='1'")
b=a["bowling_team"].value_counts()
b
# Out:
# Rajasthan Royals               20
# Royal Challengers Bangalore    13
# Kolkata Knight Riders          10
# Kings XI Punjab                 9
# Mumbai Indians                  8
# Sunrisers Hyderabad             6
# Delhi Daredevils                6
# Gujarat Lions                   5
# Chennai Super Kings             4
# Name: bowling_team, dtype: int64

# %%
df1= pd.DataFrame(data=b.index, columns=['defending_team'])
df2 = pd.DataFrame(data=b.values, columns=['super_overs'])
d2 = pd.merge(df1, df2, left_index=True, right_index=True)
d2
df3 = d2.iloc[[0]]
df3
# Out:
#      defending_team  super_overs
# 0  Rajasthan Royals           14

# %% [markdown]
# # which team has bowled maximum no balls

# %%
#which team has bowled maximum no balls
a=data2.query("noball_runs !='0'")
b=a["bowling_team"].value_counts()
b
# Out:
# Mumbai Indians                 105
# Kings XI Punjab                 96
# Royal Challengers Bangalore     91
# Delhi Daredevils                86
# Kolkata Knight Riders           77
# Rajasthan Royals                68
# Chennai Super Kings             59
# Deccan Chargers                 49
# Sunrisers Hyderabad             30
# Pune Warriors                   26
# Delhi Capitals                   8
# Kochi Tuskers Kerala             7
# Gujarat Lions                    7
# Rising Pune Supergiants          4
# Rising Pune Supergiant           1
# Name: bowling_team, dtype: int64

# %%
df1= pd.DataFrame(data=b.index, columns=['Team'])
df2 = pd.DataFrame(data=b.values, columns=['NO_BALLS'])
d2 = pd.merge(df1, df2, left_index=True, right_index=True)
d2
df3 = d2.iloc[[0]]
df3
# Out:
#              Team  NO_BALLS
# 0  Mumbai Indians       105

# %% [markdown]
# # Which player has caught maximum catches

# %%
a=data2["fielder"].value_counts()
a
# Out:
# MS Dhoni              159
# KD Karthik            152
# RV Uthappa            125
# SK Raina              115
# AB de Villiers        114
# PA Patel               97
# RG Sharma              92
# V Kohli                90
# KA Pollard             85
# NV Ojha                82
# WP Saha                82
# RA Jadeja              80
# DJ Bravo               78
# MK Pandey              77
# AC Gilchrist           75
# S Dhawan               73
# AT Rayudu              65
# DA Warner              62
# AM Rahane              62
# KC Sangakkara          58
# SV Samson              56
# DA Miller              53
# YK Pathan              51
# SPD Smith              51
# BB McCullum            50
# M Vijay                49
# MK Tiwary              49
# HH Pandya              48
# F du Plessis           47
# Harbhajan Singh        46
#                      ...
# Younis Khan             1
# Ankit Soni              1
# RG More                 1
# L Ngidi                 1
# ...

# %%
df1= pd.DataFrame(data=a.index, columns=['Player'])
df2 = pd.DataFrame(data=a.values, columns=['NO of catches'])
d2 = pd.merge(df1, df2, left_index=True, right_index=True)
d2
df3 = d2.iloc[[0]]
df3
# Out:
#      Player  NO of catches
# 0  MS Dhoni            159

# %% [markdown]
# # Which bowler has took maximum wickets

# %%
a=data2.query("player_dismissed != 'NaN' & dismissal_kind != 'run out'")
b=a["bowler"].value_counts()
b
# Out:
# Harbhajan Singh     3440
# A Mishra            3163
# PP Chawla           3150
# R Ashwin            3003
# SL Malinga          2956
# B Kumar             2699
# DJ Bravo            2690
# P Kumar             2625
# UT Yadav            2588
# SP Narine           2585
# RA Jadeja           2533
# Z Khan              2260
# DW Steyn            2199
# R Vinay Kumar       2164
# SR Watson           2122
# IK Pathan           2094
# I Sharma            1997
# A Nehra             1959
# PP Ojha             1935
# RP Singh            1864
# YS Chahal           1839
# DS Kulkarni         1825
# JA Morkel           1796
# JH Kallis           1790
# JJ Bumrah           1789
# MM Sharma           1762
# AR Patel            1740
# M Morkel            1688
# R Bhatia            1650
# M Muralitharan      1578
#                     ...
# S Midhun              13
# AA Kazi               12
# C Munro               12
# Mandeep Singh         12
# RR Bhatkal            12
# RR Bose               12
# ...

# %%
df1= pd.DataFrame(data=b.index, columns=['Bowler'])
df2 = pd.DataFrame(data=b.values, columns=['Wickets'])
d2 = pd.merge(df1, df2, left_index=True, right_index=True)
d2
df3 = d2.iloc[[0]]
df3
# Out:
#             Bowler  Wickets
# 0  Harbhajan Singh     3440

# %% [markdown]
# # which batsman has hit maximum sixes

# %%
a=data2.query("batsman_runs=='6'")
b=a["batsman"].value_counts()
b
# Out:
# CH Gayle           327
# AB de Villiers     214
# MS Dhoni           207
# SK Raina           195
# RG Sharma          194
# V Kohli            191
# DA Warner          181
# SR Watson          177
# KA Pollard         175
# YK Pathan          161
# RV Uthappa         156
# Yuvraj Singh       149
# BB McCullum        129
# AT Rayudu          120
# AD Russell         119
# DR Smith           117
# V Sehwag           106
# KD Karthik         101
# S Dhawan            96
# RR Pant             94
# AC Gilchrist        92
# M Vijay             91
# GJ Maxwell          91
# SV Samson           89
# DA Miller           87
# KL Rahul            81
# NV Ojha             79
# JP Duminy           79
# SE Marsh            78
# MK Pandey           76
#                   ...
# DE Bollinger         1
# JJ van der Wath      1
# VH Zol               1
# MN van Wyk           1
# SW Tait              1
# Anirudh Singh        1
# Anureet Singh        1
# P Sahu               1
# KW Richardson        1
# ...

# %%
df1= pd.DataFrame(data=b.index, columns=['Batsman'])
df2 = pd.DataFrame(data=b.values, columns=['NO of Sixes'])
d2 = pd.merge(df1, df2, left_index=True, right_index=True)
d2
df3 = d2.iloc[[0]]
df3
# Out:
#     Batsman  NO of Sixes
# 0  CH Gayle          327
